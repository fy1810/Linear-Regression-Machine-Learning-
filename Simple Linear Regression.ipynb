# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
s_data=pd.read_csv('studentscores.csv')
s_data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
s_data.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
s_data.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
s_data.plot(x='Hours',y='Scores',style='o')
plt.xlabel('Hours Studied')
plt.ylabel('Score Gained')
# Out:
# Text(0, 0.5, 'Score Gained')

# %%
x=s_data.iloc[:,:-1].values
y=s_data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=1,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(xtest,ytest)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [7.85998595]

# %%
print(regressor.intercept_)
# Out:
# 11.588855069070469

# %%
line=(regressor.coef_*x+regressor.intercept_)
plt.scatter(x,y)
plt.plot(x,line)

# %%
xtest
# Out:
# array([[1.1],
#        [3.3],
#        [1.9],
#        [8.5],
#        [4.8]])

# %%
ypred=regressor.predict(xtest)
ypred
# Out:
# array([20.23483962, 37.52680871, 26.52282838, 78.39873566, 49.31678764])

# %%
df=pd.DataFrame({'Actual' : ytest,'Predicted': ypred})
df
# Out:
#    Actual  Predicted
# 0      17  20.234840
# 1      42  37.526809
# 2      24  26.522828
# 3      75  78.398736
# 4      54  49.316788

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(ytest,ypred))
# Out:
# 3.662561461016151

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(ytest,ypred))
# Out:
# 14.064434558651346

# %%
from sklearn.metrics import r2_score
print(r2_score(ytest,ypred))
# Out:
# 0.9677598694327633
